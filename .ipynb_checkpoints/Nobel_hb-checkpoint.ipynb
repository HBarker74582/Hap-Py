# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np



# Read happy data
nobel_data = pd.read_csv("data/nobel_data.csv")
happy_data = pd.read_csv("2017.csv")
nobel_data
# Out:
#      Year    Category                                              Prize  \
# 0    1901   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1901  Literature                 The Nobel Prize in Literature 1901
# 2    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                         The Nobel Peace Prize 1901
# 4    1901       Peace                         The Nobel Peace Prize 1901
# 5    1901     Physics                    The Nobel Prize in Physics 1901
# 6    1902   Chemistry                  The Nobel Prize in Chemistry 1902
# 7    1902  Literature                 The Nobel Prize in Literature 1902
# 8    1902    Medicine     The Nobel Prize in Physiology or Medicine 1902
# 9    1902       Peace                         The Nobel Peace Prize 1902
# 10   1902       Peace                         The Nobel Peace Prize 1902
# 11   1902     Physics                    The Nobel Prize in Physics 1902
# ...

# %%
nobel_country = nobel_data[["Birth Country", "Death Country"]]
nobel_country.head()
# Out:
#       Birth Country Death Country
# 0       Netherlands       Germany
# 1            France        France
# 2  Prussia (Poland)       Germany
# 3       Switzerland   Switzerland
# 4            France        France

# %%
nobel_country['Birth Country'] = nobel_country['Birth Country'].replace(
   {'Prussia (Poland)': 'Poland', 'Prussia (Germany)': 'Germany', "Faroe Islands (Denmark)": "Denmark",
   "United States of America": "United States", "Austria-Hungary (Austria)": "Austria", "Russian Empire (Poland)":
    "Poland", "Schleswig (Germany)":"Germany", "Austria-Hungary (Poland":"Poland", "Union of Soviet Socialist Republics (Russia)":"Russia",
    "Union of Soviet Socialist Republics (Belarus)":"Belarus", "British Mandate of Palestine (Israel)": "Israel",
    "Austria-Hungary (Hungary)": "Hungary", "Austrian Empire (Italy)": "Italy", "Austria-Hungary (Croatia)": "Croatia", "British India (India)":"India", 
    "Bavaria (Germany)":"Germany", "Austrian Empire (Austria)":"Austria", "Tuscany (Italy)": "Italy", "West Germany (Germany)":"Germany",
    "W&uuml;rttemberg (Germany)":"Germany", "Russian Empire (Ukraine)":"Ukraine", "Poland (Belarus)":"Belarus", "Austria-Hungary (Bosnia and Herzegovina)": "Bosnia and Herzegovina",
    "Austria-Hungary (Czech Republic)": "Czech Republic", "Austria-Hungary (Poland)":"Poland", "Austria-Hungary (Slovenia)":"Solvenia",
    "Austria-Hungary (Ukraine)": "Ukraine", "Austrian Empire (Czech Republic)": "Czech Republic", "Bosnia (Bosnia and Herzegovina)": "Bosnia and Herzegovina",
    "Burma (Myanmar)":"Myanmar", "British India (Bangladesh)": "Bangladesh", "British Protectorate of Palestine (Israel)": "Israel", 
    "Czechoslovakia (Czech Republic)": "Czech Republic", "East Friesland (Germany)": "Germany", "Southern Rhodesia (Zimbabwe)":"Zimbabwe",
    "British West Indies (Saint Lucia)":"Saint Lucia", "Crete (Greece)": "Greece", "Free City of Danzig (Poland)":"Poland", "Russian Empire (Russia)": "Russia",
    "Russian Empire (Lithuania)":"Lithuania", "Russian Empire (Latvia)": "Latvia", "Russian Empire (Finland)":"Finland", "Russian Empire (Belarus)":"Belarus",
    "Germany (France)":"France", "Germany (Poland)":"Poland", "Poland (Lithuania)":"Lithuania"
    
   })
# Out:
# C:\Users\heath\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
birth = nobel_country.groupby(["Birth Country"])

birth_count = birth["Birth Country"].count()
death = birth["Death Country"].count()

new_df = pd.DataFrame({"Birth Country" : birth_count,
                       "Death Country" : death
                      
                      })


# top_spenders = pd.DataFrame({"Purchase Count" : top_count,
#                          "Average Purchase Price": round(avg_pur_top, 2),
#                          "Total Purchase Value": total_price_top})
# top_spenders_sorted = top_spenders.sort_values("Total Purchase Value", ascending=False)    
# top_spenders_sorted.head(5)

new_df.head()
# Out:
#                Birth Country  Death Country
# Birth Country
# Argentina                  4              3
# Australia                 11              5
# Austria                   19             15
# Bangladesh                 1              0
# Belarus                    4              3

# %%
x = nobel_country["Birth Country"]
x2 = happy_data["Country"]
y2 = happy_data["Happiness.Rank"]

place_birth = plt.bar(x, y, color="blue")
# happy = plt.scatter(x2, y2, marker="o", facecolors="blue", edgecolors="pink")


plt.title("Data")
plt.xlabel("Country")
plt.ylabel("Rank")
plt.grid(True)

plt.xticks(rotation=80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-a3e4f644383c> in <module>
#       3 y2 = happy_data["Happiness.Rank"]
#       4
# ----> 5 place_birth = plt.bar(x, y, color="blue")
#       6 # happy = plt.scatter(x2, y2, marker="o", facecolors="blue", edgecolors="pink")
#       7
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2455     return gca().bar(
#    2456         x, height, width=width, bottom=bottom, align=align,
# -> 2457         **({"data": data} if data is not None else {}), **kwargs)
#    2458
#    2459
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...
