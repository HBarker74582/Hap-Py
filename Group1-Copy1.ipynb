# %%
# declare variables
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time 
import requests
import json
from pprint import pprint
from config import api_key

# %%
citydata = pd.read_csv("data/worldcities1.csv")
happy = pd.read_csv("data/happy.csv")
nuke = pd.read_csv("data/Nuclear_Data.csv")


# print(citydata).head()
# print(happy).head()

nuke.count("UNITED STATES OF AMERICA")

# nuke['Country'].head
# print(nuke).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-bc8c72a20c4c> in <module>
#       7 # print(happy).head()
#       8
# ----> 9 nuke.count("UNITED STATES OF AMERICA")
#      10
#      11 # nuke['Country'].head
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
#    7314         Myla      1
#    7315         """
# -> 7316         axis = self._get_axis_number(axis)
#    7317         if level is not None:
#    7318             return self._count_level(level, axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     359                 pass
#     360         raise ValueError('No axis named {0} for object type {1}'
# --> 361                          .format(axis, type(cls)))
#     362
#     363     @classmethod
#
# ...

# %%
combined_nuke_df = pd.merge(nuke, citydata, how='outer', on='country')
combined_nuke_df
# Out:
#          FID              Region                   country  \
# 0        0.0    Europe - Western                    SWEDEN
# 1        8.0    Europe - Western                    SWEDEN
# 2       80.0    Europe - Western                    SWEDEN
# 3      184.0    Europe - Western                    SWEDEN
# 4      207.0    Europe - Western                    SWEDEN
# 5        1.0    Europe - Western                     SPAIN
# 6        4.0    Europe - Western                     SPAIN
# 7       50.0    Europe - Western                     SPAIN
# 8      120.0    Europe - Western                     SPAIN
# 9      215.0    Europe - Western                     SPAIN
# 10     250.0    Europe - Western                     SPAIN
# 11     258.0    Europe - Western                     SPAIN
# 12       2.0     America - Latin                    BRAZIL
# 13       3.0  America - Northern  UNITED STATES OF AMERICA
# 14       9.0  America - Northern  UNITED STATES OF AMERICA
# ...

# %%
# delete all values if city = NaN
combined_nuke_df= combined_nuke_df[pd.notnull(combined_nuke_df['country'])]

# %%
# Set the index of this new dataframe to be the country names
combined_nuke_df = combined_nuke_df.set_index("city")
combined_nuke_df

# %%
combined_nuke_df
