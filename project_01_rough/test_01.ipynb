# %%
# Dependencies and Setup

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Specifying csv paths

csv_path_01 = "data/worldcities.csv"
csv_path_02 = "data/happy.csv"
csv_path_03 = "data/Nuclear_Data.csv"
csv_path_04 = "data/economic freedom.csv"
csv_path_05 = "data/nobel_data.csv"

# %%
# Creating data frames

df1 = pd.read_csv("data/worldcities1.csv")
df2 = pd.read_csv("data/happy.csv")
df3 = pd.read_csv("data/Nuclear_Data.csv")
df4 = pd.read_csv("data/economic freedom.csv")
df5 = pd.read_csv("data/nobel_data.csv")

# %%
df1
# Out:
#                  city      city_ascii      lat       lng        country iso2  \
# 0               Kabul           Kabul  34.5167   69.1833    Afghanistan   AF
# 1              Sharan          Sharan  33.1757   68.7304    Afghanistan   AF
# 2              Zaranj          Zaranj  31.1120   61.8870    Afghanistan   AF
# 3         Lashkar Gah     Lashkar Gah  31.5830   64.3600    Afghanistan   AF
# 4            Kandahar        Kandahar  31.6100   65.6949    Afghanistan   AF
# 5          Tarin Kowt      Tarin Kowt  32.6333   65.8667    Afghanistan   AF
# 6               Herat           Herat  34.3300   62.1700    Afghanistan   AF
# 7              Ghazni          Ghazni  33.5633   68.4178    Afghanistan   AF
# 8        Maīdān Shahr    Maidan Shahr  34.3956   68.8662    Afghanistan   AF
# 9            Andkhvoy        Andkhvoy  36.9317   65.1015    Afghanistan   AF
# 10       Pol-e Khomri    Pol-e Khomri  35.9511   68.7011    Afghanistan   AF
# ...

# %%
df2
# Out:
#                       country  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# 5                 Switzerland       6            11             44.0
# 6                      Sweden       7            18             34.0
# 7                 New Zealand       8            15             22.0
# 8                      Canada       9            23             18.0
# 9                     Austria      10            10             64.0
# 10                  Australia      11            26             47.0
# 11                 Costa Rica      12            62              4.0
# 12                     Israel      13            14            104.0
# ...

# %%
merge_df1_df2 = pd.merge(df1,df2,on="country",how="outer")
merge_df1_df2
# Out:
#                  city      city_ascii      lat      lng  \
# 0               Kabul           Kabul  34.5167  69.1833
# 1              Sharan          Sharan  33.1757  68.7304
# 2              Zaranj          Zaranj  31.1120  61.8870
# 3         Lashkar Gah     Lashkar Gah  31.5830  64.3600
# 4            Kandahar        Kandahar  31.6100  65.6949
# 5          Tarin Kowt      Tarin Kowt  32.6333  65.8667
# 6               Herat           Herat  34.3300  62.1700
# 7              Ghazni          Ghazni  33.5633  68.4178
# 8        Maīdān Shahr    Maidan Shahr  34.3956  68.8662
# 9            Andkhvoy        Andkhvoy  36.9317  65.1015
# 10       Pol-e Khomri    Pol-e Khomri  35.9511  68.7011
# 11     Mazar-e Sharif  Mazar-e Sharif  36.7000  67.1000
# 12          Sar-e Pul       Sar-e Pul  36.2154  65.9325
# 13           Meymaneh        Meymaneh  35.9302  64.7701
# 14             Gardiz          Gardiz  33.6001  69.2146
# 15           Asadabad        Asadabad  34.8660  71.1500
# ...

# %%
sort_df1_df2 = merge_df1_df2.sort_values("country", ascending=True)
sort_df1_df2
# Out:
#                city      city_ascii      lat      lng      country iso2 iso3  \
# 0             Kabul           Kabul  34.5167  69.1833  Afghanistan   AF  AFG
# 23       Qala i Naw      Qala i Naw  34.9830  63.1333  Afghanistan   AF  AFG
# 24         Feyzabad        Feyzabad  37.1298  70.5792  Afghanistan   AF  AFG
# 25         Charikar        Charikar  35.0183  69.1679  Afghanistan   AF  AFG
# 27          Bāzārak         Bazarak  35.3129  69.5152  Afghanistan   AF  AFG
# 28           Kondoz          Kondoz  36.7280  68.8725  Afghanistan   AF  AFG
# 29            Qalat           Qalat  32.1123  66.8868  Afghanistan   AF  AFG
# 30          Taloqan         Taloqan  36.7300  69.5400  Afghanistan   AF  AFG
# 31            Balkh           Balkh  36.7501  66.8997  Afghanistan   AF  AFG
# 32          Baghlan         Baghlan  36.1393  68.6993  Afghanistan   AF  AFG
# 33           Bamian          Bamian  34.8211  67.5210  Afghanistan   AF  AFG
# ...

# %%
reindex_df1_df2 = sort_df1_df2.reset_index(drop=True)
reindex_df1_df2
# Out:
#                  city      city_ascii      lat      lng      country iso2  \
# 0               Kabul           Kabul  34.5167  69.1833  Afghanistan   AF
# 1          Qala i Naw      Qala i Naw  34.9830  63.1333  Afghanistan   AF
# 2            Feyzabad        Feyzabad  37.1298  70.5792  Afghanistan   AF
# 3            Charikar        Charikar  35.0183  69.1679  Afghanistan   AF
# 4             Bāzārak         Bazarak  35.3129  69.5152  Afghanistan   AF
# 5              Kondoz          Kondoz  36.7280  68.8725  Afghanistan   AF
# 6               Qalat           Qalat  32.1123  66.8868  Afghanistan   AF
# 7             Taloqan         Taloqan  36.7300  69.5400  Afghanistan   AF
# 8               Balkh           Balkh  36.7501  66.8997  Afghanistan   AF
# 9             Baghlan         Baghlan  36.1393  68.6993  Afghanistan   AF
# 10             Bamian          Bamian  34.8211  67.5210  Afghanistan   AF
# 11             Karokh          Karokh  34.4868  62.5918  Afghanistan   AF
# ...
