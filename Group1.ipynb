# %%
# declare variables
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time 
import requests
import json
from pprint import pprint
from config import api_key

# %%
citydata = pd.read_csv("data/worldcities1.csv")
happy = pd.read_csv("data/happy.csv")

# print(citydata).head()
# print(happy).head()

combined_happy_df = pd.merge(citydata, happy, how='outer', on='country')
# Out:
#                  city      city_ascii      lat      lng        country iso2  \
# 0               Kabul           Kabul  34.5167  69.1833    Afghanistan   AF
# 1              Sharan          Sharan  33.1757  68.7304    Afghanistan   AF
# 2              Zaranj          Zaranj  31.1120  61.8870    Afghanistan   AF
# 3         Lashkar Gah     Lashkar Gah  31.5830  64.3600    Afghanistan   AF
# 4            Kandahar        Kandahar  31.6100  65.6949    Afghanistan   AF
# 5          Tarin Kowt      Tarin Kowt  32.6333  65.8667    Afghanistan   AF
# 6               Herat           Herat  34.3300  62.1700    Afghanistan   AF
# 7              Ghazni          Ghazni  33.5633  68.4178    Afghanistan   AF
# 8        Maīdān Shahr    Maidan Shahr  34.3956  68.8662    Afghanistan   AF
# 9            Andkhvoy        Andkhvoy  36.9317  65.1015    Afghanistan   AF
# 10       Pol-e Khomri    Pol-e Khomri  35.9511  68.7011    Afghanistan   AF
# ...

# %%
# delete all values if city = NaN
combined_happy_df= combined_happy_df[pd.notnull(combined_happy_df['city'])]

# %%
# Set the index of this new dataframe to be the country names
combined_happy_df = combined_happy_df.set_index("city")
combined_happy_df
# Out:
#                     city_ascii      lat       lng                  country  \
# city
# Kabul                    Kabul  34.5167   69.1833              Afghanistan
# Sharan                  Sharan  33.1757   68.7304              Afghanistan
# Zaranj                  Zaranj  31.1120   61.8870              Afghanistan
# Lashkar Gah        Lashkar Gah  31.5830   64.3600              Afghanistan
# Kandahar              Kandahar  31.6100   65.6949              Afghanistan
# Tarin Kowt          Tarin Kowt  32.6333   65.8667              Afghanistan
# Herat                    Herat  34.3300   62.1700              Afghanistan
# Ghazni                  Ghazni  33.5633   68.4178              Afghanistan
# Maīdān Shahr      Maidan Shahr  34.3956   68.8662              Afghanistan
# Andkhvoy              Andkhvoy  36.9317   65.1015              Afghanistan
# Pol-e Khomri      Pol-e Khomri  35.9511   68.7011              Afghanistan
# ...

# %%
combined_happy_df
# Out:
#                     city_ascii      lat       lng                  country  \
# city
# Kabul                    Kabul  34.5167   69.1833              Afghanistan
# Sharan                  Sharan  33.1757   68.7304              Afghanistan
# Zaranj                  Zaranj  31.1120   61.8870              Afghanistan
# Lashkar Gah        Lashkar Gah  31.5830   64.3600              Afghanistan
# Kandahar              Kandahar  31.6100   65.6949              Afghanistan
# Tarin Kowt          Tarin Kowt  32.6333   65.8667              Afghanistan
# Herat                    Herat  34.3300   62.1700              Afghanistan
# Ghazni                  Ghazni  33.5633   68.4178              Afghanistan
# Maīdān Shahr      Maidan Shahr  34.3956   68.8662              Afghanistan
# Andkhvoy              Andkhvoy  36.9317   65.1015              Afghanistan
# Pol-e Khomri      Pol-e Khomri  35.9511   68.7011              Afghanistan
# ...
